# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\macie\OneDrive\Dokumenty\GitHub\ExpeRespo\Model_I_SImulation\Server_Metrics.csv"
server_metrics = pd.read_csv(path, names=['Accuracy'], index_col=0)

# %%
server_metrics.plot()
# Out:
# <AxesSubplot:>

# %%
path = r"C:\Users\macie\OneDrive\Dokumenty\GitHub\ExpeRespo\Model_I_SImulation\Aggregated_Metrics.csv"
columns = []
for i in range(5):
    columns.append("C{} Accuracy".format((i+1)))
for i in range(5):
    columns.append("C{} Number of examples".format((i+1)))
client_metrics = pd.read_csv(path, index_col=0, names=columns)

# %%
client_metrics
# Out:
#     C1 Accuracy  C2 Accuracy  C3 Accuracy  C4 Accuracy  C5 Accuracy  \
# 1         0.723        0.723        0.680        0.733        0.674
# 2         0.734        0.741        0.743        0.712        0.759
# 3         0.791        0.853        0.831        0.909        0.769
# 4         0.805        0.807        0.814        0.817        0.914
# 5         0.805        0.880        0.889        0.805        0.790
# 6         0.893        0.815        0.886        0.881        0.825
# 7         0.814        0.831        0.934        0.893        0.885
# 8         0.821        0.823        0.905        0.937        0.826
# 9         0.826        0.890        0.834        0.941        0.905
# 10        0.887        0.832        0.895        0.915        0.844
# 11        0.877        0.836        0.950        0.837        0.896
# 12        0.841        0.851        0.907        0.839        0.879
# 13        0.846        0.887        0.857        0.954        0.919
# ...

# %%
client_metrics.iloc[:, 0:5].plot()
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)

ax.set_ylabel("Training round")
ax.set_xlabel("Accuracy")
ax.plot(server_metrics, "r-", label='Central Accuracy', linewidth=2.5)
ax.plot(client_metrics['C1 Accuracy'], 'b--', label='C1 Accuracy')
ax.plot(client_metrics['C2 Accuracy'], 'g--', label='C2 Accuracy')
ax.plot(client_metrics['C3 Accuracy'], 'c--', label='C3 Accuracy')
ax.plot(client_metrics['C4 Accuracy'], 'm--', label='C4 Accuracy')
ax.plot(client_metrics['C5 Accuracy'], 'y--', label='C5 Accuracy')

fig.show()
fig.legend()
# Out:
# C:\Users\macie\AppData\Local\Temp\ipykernel_17448\195038686.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)

ax.set_ylabel("Training round")
ax.set_xlabel("Accuracy")
ax.plot(server_metrics, "r--", label='Central Accuracy', linewidth=1)
ax.plot(client_metrics['C3 Accuracy'], 'c-', label='C3 Accuracy')
ax.plot(client_metrics['C5 Accuracy'], 'y-', label='C5 Accuracy')

fig.show()
fig.legend()
# Out:
# C:\Users\macie\AppData\Local\Temp\ipykernel_17448\1929765757.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
